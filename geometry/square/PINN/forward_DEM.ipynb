# %%
# (for Google Colab)
# !pip install pyDOE
# !pip install tfp-nightly

# %%
import os, time, pickle
import jax, flax, optax
import jax.numpy as np
from jax.nn.initializers import normal
import numpy as onp
from scipy.optimize import minimize
from functools import partial
from pyDOE import lhs
from typing import Sequence, Callable, Union, Dict
import json
from tensorflow_probability.substrates import jax as tfp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Must set CUDA_VISIBLE_DEVICES before importing JAX or any other library that initializes GPUs.
# Otherwise, the environment variable change might be ignored.
# "0, 1": first two GPUs / "": no GPU (CPU instead)

# Run on the first GPU
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
from jax.extend.backend import get_backend
print(get_backend().platform)
# Out:
# gpu

# %% [markdown]
# # Global Variables

# %%
side_length = 1.
k = 100.
geo_params = np.array([0.25, 0.25, 0.5, 6/20, float(onp.pi/3)])
# for no hole case
# geo_params = np.array([0.25, 0.25, 0., 0., float(onp.pi/3)])
pickle_params = True

# %% [markdown]
# # Hyperparameters

# %%
architecture_list = [[58, 58, 58, 2]]
lr = 2e-04 # learning rate
num_epochs = 40000 # number of training epochs
TV_weight = 1e-3
# Fourier feature mapping
fourier_emb_config = {"scale": 5.4, # This is the crucial 'σ' hyper-parameter
                        "dim": 10,}   # The output dimension of the embedding

# %% [markdown]
# # NN Architecture

# %%
# Define NN architecture
class PDESolution(flax.linen.Module): # inherit from Module class
    # One behavior of "flax.linen.Module" is to assign the provided argument to the "self.features"
    features: Sequence[int] # dataclass (e.g. [10, 20, 2])
    fourier_features: Union[None, Dict] = None

    @flax.linen.compact # a decorator to define the model in more concise and readable way
    def __call__(self, x): # __call__: makes an object callable, which enables you to use instances of the class like functions
        if self.fourier_features:
            x = FourierEmbbeding(**self.fourier_features)(x) # ** : dictionary unpacking operator
        for feature in self.features[:-1]:
            x = flax.linen.tanh(flax.linen.Dense(feature)(x))
        # Final Dense layer
        x = flax.linen.Dense(self.features[-1])(x)
        return x

# %% [markdown]
# # Fourier Feature Embedding

# %%
# Mapping u(x)=NN(γ(x))
class FourierEmbbeding(flax.linen.Module):
    scale: float
    dim: int

    @flax.linen.compact
    def __call__(self, x):
        # Define random 'kernel' parameters in the network
        kernel = self.param('kernel', normal(self.scale), # Sample from N(0, σ²)
                            (x.shape[-1], self.dim // 2)) # shape of parameter
        # Projection from input vectors(x) -> random frequency vectors(γ(x))
        return np.concatenate([np.cos(np.dot(x, kernel)), np.sin(np.dot(x, kernel))], axis=-1)

# %% [markdown]
# # Dirichlet Boundary Conditions

# %%
# Wrapper to apply Dirichlet BCs
# TODO: integrate other calculations into here as well
class ElasticityPINN(flax.linen.Module):
    features: Sequence[int]
    fourier_features: Union[None, Dict] = None

    # The setup() method is the standard place to define submodule with Flax.
    # It runs right before the model is called.
    def setup(self):
        self.model = PDESolution(self.features,
                                 fourier_features = self.fourier_features)

    def __call__(self, coords): # coords : (n, 2)
        # Raw output from the sub-module
        model_output = self.model(coords)
        x_coords = coords[:, 0]
        y_coords = coords[:, 1]

        # Hard-coded Dirichlet BCs
        u1 = (x_coords - 1) * (x_coords + 1) * model_output[:, 0] + 0.05 * x_coords
        u2 = (x_coords - 1) * (x_coords + 1) * model_output[:, 1] # Γ_u = 0 at y = -1, 1

        return np.stack([u1, u2], axis=1)

# %% [markdown]
# # Gaussian Quadrature

# %%
def linear_transform(x, a, b, c=-1, d=1):
    return (b - a) / (d - c) * x + (a * d - b * c) / (d - c)

# Generate 1D points
def get_1D_quad_point(num_elems, num_gauss):
    # Gauss quadrature points & weights on [-1, 1]
    gauss_pts, gauss_weights = onp.polynomial.legendre.leggauss(num_gauss)

    # Mesh (points) generation
    mesh_pts = onp.linspace(-side_length, side_length, num_elems + 1)

    coords, weights = [], []
    for i in range(num_elems):
        # Vertices of the mesh
        a, b = mesh_pts[i], mesh_pts[i+1]

        # Linear transformation (Gauss points -> Physical points)
        physical_pts = linear_transform(gauss_pts, a, b) # (num_gauss,)

        # Jacobian (length of element / 2)
        J = 0.5 * (b - a)

        coords.append(physical_pts) # (n, num_gauss)
        weights.append(J * gauss_weights)

    return onp.array(coords).flatten(), onp.array(weights).flatten() # (n, num_gauss), (n, num_gauss) -> (n*num_gauss), (n*num_gauss)

# Generate 2D points
def get_2D_quad_point(x_elems, y_elems, num_gauss):
    # Gauss quadrature points & weights on [-1, 1] x [-1, 1]
    gauss_pts, gauss_weights = onp.polynomial.legendre.leggauss(num_gauss)

    # Generate weights on the all the grid points
    gauss_weight_x, gauss_weight_y = onp.meshgrid(gauss_weights, gauss_weights, indexing='ij') # if same quad pts in both axes, same results regardless of indexing
    gauss_weight_x, gauss_weight_y = gauss_weight_x.flatten(), gauss_weight_y.flatten()
    gauss_weight_total = gauss_weight_x * gauss_weight_y # weight at 2D points is the product of 1D weights

    # Generate points on the all the grid points
    # these grid points are used only for generating integration points, not for integration itself
    x_pts = onp.linspace(-side_length, side_length, x_elems + 1)
    y_pts = onp.linspace(-side_length, side_length, y_elems + 1)
    mesh_x, mesh_y = onp.meshgrid(x_pts, y_pts, indexing='ij')
    # mesh_x, mesh_y = mesh_x.flatten(), mesh_y.flatten()
    # mesh_pts = onp.array([mesh_x, mesh_y]).T

    # Iterate over each element
    coords, weights = [], []
    for j in range(y_elems):
        for i in range(x_elems):
            # Vertices of the mesh
            a_x, b_x = mesh_x[j, i], mesh_x[j+1, i] # since slicing structure as (row, col), while Cartesian coords structure as (x, y)
            a_y, b_y = mesh_y[j, i], mesh_y[j, i+1]

            # Linear transformation (Gauss points -> Physical points)
            physical_x = linear_transform(gauss_pts, a_x, b_x)
            physical_y = linear_transform(gauss_pts, a_y, b_y)

            coords_x, coords_y = onp.meshgrid(physical_x, physical_y, indexing='ij')
            coords_x, coords_y = coords_x.flatten(), coords_y.flatten()

            #Jacobian (length of element / 2)
            J = (b_x - a_x) * (b_y - a_y) / 4

            coords.append(onp.array([coords_x, coords_y]).T)
            weights.append(J * gauss_weight_total)

    return onp.array(coords).reshape(-1, 2), onp.array(weights).flatten()

# %% [markdown]
# # Mesh Generation

# %%
# Quadrature Parameters
x_elems = 50 # Number of elements for boundary integration
y_elems = 50
num_gauss = 3 # Number of Gauss points per element

# Boundary points
boundary_pts, boundary_weights = get_1D_quad_point(x_elems, num_gauss)
top_boundary_coords = np.stack((boundary_pts, side_length * np.ones_like(boundary_pts)), axis=1)
bot_boundary_coords = np.stack((boundary_pts, -side_length * np.ones_like(boundary_pts)), axis=1)
# (y coord will be not used, so -side_length for y=bottom is not defined here...)

# Domain points
domain_coords, domain_weights = get_2D_quad_point(x_elems, y_elems, num_gauss)

# %% [markdown]
# # Loss Function

# %%
# Energy residual (each quadrature point)
@partial(jax.vmap, in_axes = (None, 0, 0, 0, None), out_axes = 0)
@partial(jax.jit, static_argnums = (0,))
def strain_energy(u, x, y, weights, geo_params):
    def stress(x, y): # tensor
        dim = 2
        E = 1.0e3
        nu = 0.33
        mu = E / (2. * (1 + nu))
        lmbda = E * nu / ((1 + nu) * (1 - 2*nu))
        def u_vec(coords): # make (n, 2)
            return u(coords[0], coords[1])
        u_jac = jax.jacrev(u_vec) # (2, 2) Jacobian matrix
        u_jac_val = u_jac(np.array([x, y]))
        epsilon = 0.5 * (u_jac_val + u_jac_val.T) # (2, 2)
        # Stress-Strain relationship
        sigma = lmbda * np.trace(epsilon) * np.eye(dim) + 2 * mu * epsilon
        return sigma, epsilon
    sigma, epsilon = stress(x, y)

    def ellipse(x, y, x_cen, y_cen, a, b, gamma) -> np.ndarray:
        """
        Get indices of cells inside the ellipse (only 2D available).
        point_idx : (+): outside, (-): inside
        """
        point_idx = jax.nn.sigmoid(k * (((x - x_cen) * np.cos(gamma) + (y - y_cen) * np.sin(gamma))**2 / a**2 +
                                        ((x - x_cen) * np.sin(gamma) - (y - y_cen) * np.cos(gamma))**2 / b**2 - 1))
        return point_idx # (n,)

    # Strain energy density (σ:𝜀 = σ_ij * 𝜀_ij)
    energy_density = np.einsum('ij,ij->', sigma, epsilon) # (n,)
    # bij : 3D tensor with axis 0 'b', axis 1 'i', and axis 2 'j'
    # = sigma[b, i, j] * epsilon[b, i, j]

    x_cen, y_cen, a, b, gamma = geo_params

    # Make weight to be zero inside the void
    weights_ellipse = weights * ellipse(x, y, x_cen, y_cen, a, b, gamma)

    return energy_density * weights_ellipse

# Work residual (each quadrature point)
@partial(jax.vmap, in_axes=(None, 0, 0, 0), out_axes=0)
@jax.jit
def external_work(params, x, y, weights):
    # Reshape input to (1, 2) and flatten output to (2,) for jacrev
    u = lambda x, y: model.apply(params, np.array([[x, y]])).squeeze()

    def traction(u, x, y):
        # Stress tensor
        def stress(x, y):
            dim = 2
            E = 1.0e3
            nu = 0.33
            mu = E / (2. * (1 + nu))
            lmbda = E * nu / ((1 + nu) * (1 - 2*nu))
            def u_vec(coords): # make (n, 2)
                return u(coords[0], coords[1])
            u_jac = jax.jacrev(u_vec) # (2, 2) Jacobian matrix
            u_jac_val = u_jac(np.array([x, y]))
            epsilon = 0.5 * (u_jac_val + u_jac_val.T) # (2, 2)
            # Stress-Strain relationship
            sigma = lmbda * np.trace(epsilon) * np.eye(dim) + 2 * mu * epsilon
            return sigma

        # Normal vector
        line_unit_normal1 = np.array([0., -1.]) # at line y = -side_length
        line_unit_normal2 = np.array([0., 1.]) # at line y = side_length

        # Traction
        traction1 = np.dot(stress(x, y), line_unit_normal1) # (n, 2) at x = -1
        traction2 = np.dot(stress(x, y), line_unit_normal2) # at x = 1
        return traction1, traction2

    # Work per point: t . u
    # work_point1 = np.dot(u(x, y), traction(u, x, y)[0]) # bot
    # work_point2 = np.dot(u(x, y), traction(u, x, y)[1]) # top
    work_point1 = np.dot(u(x, y), 0 * np.ones_like(u(x, y))) # bot
    work_point2 = np.dot(u(x, y), 0 * np.ones_like(u(x, y))) # top

    return work_point1 * weights, work_point2 * weights

# Loss functionals
@jax.jit
def energy_residual(params, points, weights, geo_params):
    return 0.5 * np.sum(strain_energy(lambda x, y: model.apply(params, np.array([[x, y]])).squeeze(), points[:, 0], points[:, 1], weights, geo_params))

@jax.jit
def work_residual1(params, points, weights): # top
    return np.sum(external_work(params, points[:, 0], points[:, 1], weights)[1])

@jax.jit
def work_residual2(params, points, weights): # bot
    return np.sum(external_work(params, points[:, 0], points[:, 1], weights)[0])

# %% [markdown]
# # Total Variation Regularization

# %%
# Isotropic TV (L2) Loss
def TV_reg(u, epsilon = 1e-6):
    """
    Args:
        epsilon: small value to avoid division by zero
    """
    grad_x = u - np.roll(u, shift = 1, axis = 1) # np.roll: shifts the entire image one pixel to the right
    grad_y = u - np.roll(u, shift = 1, axis = 0)

    return np.sum(np.sqrt(grad_x**2 + grad_y**2 + epsilon))

# %% [markdown]
# # Training Loop

# %%
# Total loss functional
def loss_total(params, domain_coords, domain_weights, top_boundary_coords, bot_boundary_coords, boundary_weights, geo_params):
    W_int = energy_residual(params, domain_coords, domain_weights, geo_params)
    # Neumann BCs are satisfied by minimizing the mean error at the integration pts
    # W_ext1 = work_residual1(params, top_boundary_coords, boundary_weights)
    # W_ext2 = work_residual2(params, bot_boundary_coords, boundary_weights)
    TV_loss = TV_reg(model.apply(params, np.stack((domain_coords[:, 0], domain_coords[:, 1]), axis=1)))

    W_total = W_int + TV_weight * TV_loss # - (W_ext1 + W_ext2)

    # For logging purposes
    individual_losses = {'strain_energy': W_int, 'external_work': W_int}

    return W_total, individual_losses

@partial(jax.jit, static_argnums=(1,))
def training_step(params, opt, opt_state, domain_coords, domain_weights, top_boundary_coords, bot_boundary_coords, boundary_weights, geo_params):
    """Performs one step of optimization."""
    (loss_val, individual_losses), grad = jax.value_and_grad(lambda x:
                                                             loss_total(x, domain_coords, domain_weights,
                                                                        top_boundary_coords, bot_boundary_coords,
                                                                        boundary_weights, geo_params),
                                                             has_aux=True)(params)

    update, opt_state = opt.update(grad, opt_state, params)
    params = optax.apply_updates(params, update)
    return params, opt_state, loss_val, individual_losses

# Training loop
def train_loop(params, adam, opt_state, domain_coords, domain_weights, top_boundary_coords, bot_boundary_coords, boundary_weights, geo_params):
    loss_history = {'total': [], 'strain_energy': [], 'external_work': []}
    for epoch in range(num_epochs): # "_" is used because the variable is not used in for loop
        params, opt_state, loss_val, individual_losses = training_step(params, adam, opt_state, domain_coords, domain_weights, top_boundary_coords, bot_boundary_coords, boundary_weights, geo_params)
        if (epoch + 1) % 100 == 0:
            print(f"Epoch: {epoch + 1}, Total Loss:{loss_val:.4e}")
            # Append the current loss values to their respective lists
            loss_history['total'].append(loss_val.item())
            for loss_name, loss_value in individual_losses.items():
                loss_history[loss_name].append(loss_value.item())
    return loss_history, params, opt_state, loss_val # return final values

# %% [markdown]
# # Helper Functions for L-BFGS Wrapper

# %%
# L-BFGS requires the parameters to be a single flattened array!
def concat_params(params): # flatten the parameters
    params, tree = jax.tree_util.tree_flatten(params) # "params" is flattened to a list of arrays
    shapes = [param.shape for param in params] # shape of each array in the "params" list
    return np.concatenate([param.reshape(-1) for param in params]), tree, shapes # concat to single 1D array

def unconcat_params(params, tree, shapes): # unflatten the parameters
    split_vec = np.split(params, onp.cumsum([onp.prod(shape, dtype=onp.int32) for shape in shapes])) # "np.cumsum" figures out the boundaries where to split the flattened "params"
    split_vec = [vec.reshape(*shape) for vec, shape in zip(split_vec, shapes)] # reshape slices of vector ("*" unpack the tuple into individual arguments)
    return jax.tree_util.tree_unflatten(tree, split_vec)

# %% [markdown]
# # Evaluation Points & Ground Truth Solutions

# %%
# Create evaluation points
x_points = np.linspace(-side_length, side_length, 200 + 1)
y_points = np.linspace(-side_length, side_length, 200 + 1)
X, Y = np.meshgrid(x_points, y_points, indexing='ij')
X, Y = X.flatten(), Y.flatten()
eval_points = np.array([X, Y]).T

# Load evaluation solutions (by Ground Truth FEM)
with open('data/eval_solutions-size_L.json', 'r') as f:
    eval_sol = json.load(f)

# Ground truth soution (200 x 200 cells)
u_true = np.array(eval_sol) # shape: (n_points, 2)

print("Evaluation points: ", np.array(eval_points).shape)
# Out:
# Evaluation points:  (40401, 2)

# %% [markdown]
# # Load the Parameters for Transfer Learning

# %%
with open('data/PINNs_params_arch_60_60_60_60_60_2.pkl', "rb") as f:
    loaded_params = pickle.load(f)

# %% [markdown]
# # Train PINN & Approximate Solution

# %%
# Containers for the results
y_results, domain_pts, times_adam, times_lbfgs, times_total, times_eval, l2_rel, arch, losses\
    = {}, {}, {}, {}, {}, {}, {}, {}, {}

count = 0 # architecture index
for architecture in architecture_list :
    print('Architecture : %s' %architecture)

    # Initialize Model
    model = ElasticityPINN(architecture, fourier_features = fourier_emb_config)

    # Initial parameters
    # "flax.linen.Module.init(key, dummy_input)" triggers "__call__" (like ".apply") and infers the shape of weights & biases
    if 'loaded_params' in globals(): # Transfer learning
        params = loaded_params
    else: # No transfer learning
        # where "key" is JAX-made PRNG key and "dummy_input" is the dummy input data.
        key = jax.random.PRNGKey(0) # create two keys for independent use
        batch_dim = 8 # dummy number(can be any value). Batch dimension will be reshaped after running "model.init".
        feature_dim = 2 # dimension of input point (x, y coord)
        params = model.init(key, np.ones((batch_dim, feature_dim))) # net_params: weights & biases initialized randomly

    # Initialize Adam Optimizer
    adam = optax.adam(learning_rate = lr)
    opt_state = adam.init(params) # opt_state : internal states of the Adam optimizer

    # Start Training with Adam Optimizer
    start_time = time.time()
    loss_history, params, opt_state, loss_val = jax.block_until_ready(train_loop(params, adam, opt_state,
                                                                                 domain_coords, domain_weights,
                                                                                 top_boundary_coords, bot_boundary_coords,
                                                                                 boundary_weights, geo_params))
    adam_time = time.time() - start_time
    print('Adam Training Time : %f secs' %adam_time)

    init_point, tree, shapes = concat_params(params)

    # L-BFGS Optimization
    print('Starting L-BFGS Optimization')
    start_time2 = time.time()
    results = tfp.optimizer.lbfgs_minimize(jax.value_and_grad(lambda x: loss_total(unconcat_params(x, tree, shapes),
                                                                                   domain_coords, domain_weights,
                                                                                   top_boundary_coords, bot_boundary_coords,
                                                                                   boundary_weights,
                                                                                   geo_params)[0]),
                                           init_point,
                                           max_iterations = 50000,
                                           num_correction_pairs = 50, # number of past updates to use for the approximation of the Hessian inverse.
                                           f_relative_tolerance = 1.0*np.finfo(float).eps) # stopping criterion
    lbfgs_time = time.time() - start_time2
    total_time = adam_time + lbfgs_time
    print("L-BFGS training time : %.3f secs" % lbfgs_time)

    # Comparison to Ground Truth
    tuned_params = unconcat_params(results.position, tree, shapes)

    # Pickle parameters for transfer learning
    if pickle_params == True:
        arch_str = '_'.join(map(str, architecture))
        params_filename = f"PINNs_params_arch_{arch_str}.pkl"
        # It's good practice to convert JAX arrays to NumPy arrays before pickling
        params_to_save = jax.device_get(tuned_params)
        with open(params_filename, "wb") as f:
            pickle.dump(params_to_save, f)
        print(f"✅ Saved final model parameters to {params_filename}")

    start_time3 = time.time()
    # Pass the "eval_points" to the trained model
    u_approx = jax.block_until_ready(model.apply(tuned_params, np.stack((eval_points[:, 0], eval_points[:, 1]), axis=1)))
    eval_time = time.time() - start_time3

    # MSE
    run_accuracy = (onp.linalg.norm(u_approx - u_true)) / onp.linalg.norm(u_true) # relative L2 error

    y_gt = u_true.tolist() # for storing into dict
    y_results[count] = u_approx.tolist()
    domain_pts[count] = eval_points.tolist()
    times_adam[count] = adam_time
    times_lbfgs[count] = lbfgs_time
    times_total[count] = total_time
    times_eval[count] = eval_time
    l2_rel[count] = onp.mean(run_accuracy).tolist()
    arch[count] = architecture_list[count]
    losses[count] = loss_history
    count += 1


    results = dict({'domain_pts': domain_pts,
                    'y_results': y_results,
                    'y_gt': y_gt})

    evaluation = dict({'arch': arch,
                       'times_adam': times_adam,
                       'times_lbfgs': times_lbfgs,
                       'times_total': times_total,
                       'times_eval': times_eval,
                       'l2_rel': l2_rel,
                       'losses_adam': losses})

    sol_json = 'PINNs_results.json'
    with open(sol_json, "w") as f:
        json.dump(results, f)

    eval_json = 'PINNs_evaluation.json'
    with open(eval_json, "w") as f:
        json.dump(evaluation, f)
# Out:
# Architecture : [58, 58, 58, 2]
# Epoch: 100, Total Loss:2.7565e+02
# Epoch: 200, Total Loss:1.2071e+02
# Epoch: 300, Total Loss:7.2867e+01
# Epoch: 400, Total Loss:5.1059e+01
# Epoch: 500, Total Loss:3.8918e+01
# Epoch: 600, Total Loss:3.1267e+01
# Epoch: 700, Total Loss:2.6083e+01
# Epoch: 800, Total Loss:2.2368e+01
# Epoch: 900, Total Loss:1.9610e+01
# Epoch: 1000, Total Loss:1.7511e+01
# Epoch: 1100, Total Loss:1.5865e+01
# Epoch: 1200, Total Loss:1.4546e+01
# Epoch: 1300, Total Loss:1.3471e+01
# Epoch: 1400, Total Loss:1.2573e+01
# Epoch: 1500, Total Loss:1.1824e+01
# Epoch: 1600, Total Loss:1.1191e+01
# Epoch: 1700, Total Loss:1.0641e+01
# Epoch: 1800, Total Loss:1.0168e+01
# Epoch: 1900, Total Loss:9.7520e+00
# Epoch: 2000, Total Loss:9.3848e+00
# Epoch: 2100, Total Loss:9.0553e+00
# Epoch: 2200, Total Loss:8.7687e+00
# Epoch: 2300, Total Loss:8.5108e+00
# Epoch: 2400, Total Loss:8.2758e+00
# Epoch: 2500, Total Loss:8.0664e+00
# Epoch: 2600, Total Loss:7.8739e+00
# Epoch: 2700, Total Loss:7.7007e+00
# Epoch: 2800, Total Loss:7.5425e+00
# Epoch: 2900, Total Loss:7.3969e+00
# Epoch: 3000, Total Loss:7.2650e+00
# Epoch: 3100, Total Loss:7.1431e+00
# Epoch: 3200, Total Loss:7.0322e+00
# Epoch: 3300, Total Loss:6.9246e+00
# Epoch: 3400, Total Loss:6.8320e+00
# Epoch: 3500, Total Loss:6.7436e+00
# Epoch: 3600, Total Loss:6.6634e+00
# Epoch: 3700, Total Loss:6.5875e+00
# Epoch: 3800, Total Loss:6.5138e+00
# Epoch: 3900, Total Loss:6.4487e+00
# Epoch: 4000, Total Loss:6.3862e+00
# Epoch: 4100, Total Loss:6.3293e+00
# Epoch: 4200, Total Loss:6.2756e+00
# Epoch: 4300, Total Loss:6.2248e+00
# Epoch: 4400, Total Loss:6.1761e+00
# Epoch: 4500, Total Loss:6.1320e+00
# Epoch: 4600, Total Loss:6.0896e+00
# Epoch: 4700, Total Loss:6.0496e+00
# Epoch: 4800, Total Loss:6.0117e+00
# Epoch: 4900, Total Loss:5.9772e+00
# Epoch: 5000, Total Loss:5.9424e+00
# Epoch: 5100, Total Loss:5.9137e+00
# Epoch: 5200, Total Loss:5.8807e+00
# Epoch: 5300, Total Loss:5.8525e+00
# Epoch: 5400, Total Loss:5.8237e+00
# Epoch: 5500, Total Loss:5.8003e+00
# Epoch: 5600, Total Loss:5.7751e+00
# Epoch: 5700, Total Loss:5.7519e+00
# Epoch: 5800, Total Loss:5.7297e+00
# Epoch: 5900, Total Loss:5.7104e+00
# Epoch: 6000, Total Loss:5.6910e+00
# Epoch: 6100, Total Loss:5.6712e+00
# Epoch: 6200, Total Loss:5.6565e+00
# Epoch: 6300, Total Loss:5.6418e+00
# Epoch: 6400, Total Loss:5.6246e+00
# Epoch: 6500, Total Loss:5.6071e+00
# Epoch: 6600, Total Loss:5.5970e+00
# Epoch: 6700, Total Loss:5.5835e+00
# Epoch: 6800, Total Loss:5.5696e+00
# Epoch: 6900, Total Loss:5.5550e+00
# Epoch: 7000, Total Loss:5.5602e+00
# Epoch: 7100, Total Loss:5.5830e+00
# Epoch: 7200, Total Loss:5.5416e+00
# Epoch: 7300, Total Loss:5.5147e+00
# Epoch: 7400, Total Loss:5.5128e+00
# Epoch: 7500, Total Loss:5.5168e+00
# Epoch: 7600, Total Loss:5.4955e+00
# Epoch: 7700, Total Loss:5.4788e+00
# Epoch: 7800, Total Loss:5.4711e+00
# Epoch: 7900, Total Loss:5.4704e+00
# Epoch: 8000, Total Loss:5.4584e+00
# Epoch: 8100, Total Loss:5.4827e+00
# Epoch: 8200, Total Loss:5.4547e+00
# Epoch: 8300, Total Loss:5.4575e+00
# Epoch: 8400, Total Loss:5.4307e+00
# Epoch: 8500, Total Loss:5.4338e+00
# Epoch: 8600, Total Loss:5.4419e+00
# Epoch: 8700, Total Loss:5.4163e+00
# Epoch: 8800, Total Loss:5.4146e+00
# Epoch: 8900, Total Loss:5.4173e+00
# Epoch: 9000, Total Loss:5.4068e+00
# Epoch: 9100, Total Loss:5.4003e+00
# Epoch: 9200, Total Loss:5.3956e+00
# Epoch: 9300, Total Loss:5.3982e+00
# Epoch: 9400, Total Loss:5.3875e+00
# Epoch: 9500, Total Loss:5.3815e+00
# Epoch: 9600, Total Loss:5.3951e+00
# Epoch: 9700, Total Loss:5.3843e+00
# Epoch: 9800, Total Loss:5.3711e+00
# Epoch: 9900, Total Loss:5.3814e+00
# Epoch: 10000, Total Loss:5.3738e+00
# Epoch: 10100, Total Loss:5.3772e+00
# Epoch: 10200, Total Loss:5.3584e+00
# Epoch: 10300, Total Loss:5.3552e+00
# Epoch: 10400, Total Loss:5.3541e+00
# Epoch: 10500, Total Loss:5.3680e+00
# Epoch: 10600, Total Loss:5.3497e+00
# Epoch: 10700, Total Loss:5.3701e+00
# Epoch: 10800, Total Loss:5.3560e+00
# Epoch: 10900, Total Loss:5.3506e+00
# Epoch: 11000, Total Loss:5.3463e+00
# Epoch: 11100, Total Loss:5.3424e+00
# Epoch: 11200, Total Loss:5.3423e+00
# Epoch: 11300, Total Loss:5.3410e+00
# Epoch: 11400, Total Loss:5.3424e+00
# Epoch: 11500, Total Loss:5.3316e+00
# Epoch: 11600, Total Loss:5.3363e+00
# Epoch: 11700, Total Loss:5.3384e+00
# Epoch: 11800, Total Loss:5.3421e+00
# Epoch: 11900, Total Loss:5.3274e+00
# Epoch: 12000, Total Loss:5.3345e+00
# Epoch: 12100, Total Loss:5.3232e+00
# Epoch: 12200, Total Loss:5.3303e+00
# Epoch: 12300, Total Loss:5.3218e+00
# Epoch: 12400, Total Loss:5.3370e+00
# Epoch: 12500, Total Loss:5.3369e+00
# Epoch: 12600, Total Loss:5.3204e+00
# Epoch: 12700, Total Loss:5.3222e+00
# Epoch: 12800, Total Loss:5.3417e+00
# Epoch: 12900, Total Loss:5.3198e+00
# Epoch: 13000, Total Loss:5.3151e+00
# Epoch: 13100, Total Loss:5.3116e+00
# Epoch: 13200, Total Loss:5.3512e+00
# Epoch: 13300, Total Loss:5.3116e+00
# Epoch: 13400, Total Loss:5.3114e+00
# Epoch: 13500, Total Loss:5.3402e+00
# Epoch: 13600, Total Loss:5.3083e+00
# Epoch: 13700, Total Loss:5.3105e+00
# Epoch: 13800, Total Loss:5.3048e+00
# Epoch: 13900, Total Loss:5.3210e+00
# Epoch: 14000, Total Loss:5.3036e+00
# Epoch: 14100, Total Loss:5.3101e+00
# Epoch: 14200, Total Loss:5.3166e+00
# Epoch: 14300, Total Loss:5.3074e+00
# Epoch: 14400, Total Loss:5.3109e+00
# Epoch: 14500, Total Loss:5.3000e+00
# Epoch: 14600, Total Loss:5.3051e+00
# Epoch: 14700, Total Loss:5.3078e+00
# Epoch: 14800, Total Loss:5.3009e+00
# Epoch: 14900, Total Loss:5.3027e+00
# Epoch: 15000, Total Loss:5.3327e+00
# Epoch: 15100, Total Loss:5.3019e+00
# Epoch: 15200, Total Loss:5.3104e+00
# Epoch: 15300, Total Loss:5.3051e+00
# Epoch: 15400, Total Loss:5.3022e+00
# Epoch: 15500, Total Loss:5.3038e+00
# Epoch: 15600, Total Loss:5.3080e+00
# Epoch: 15700, Total Loss:5.2984e+00
# Epoch: 15800, Total Loss:5.3070e+00
# Epoch: 15900, Total Loss:5.2931e+00
# Epoch: 16000, Total Loss:5.2914e+00
# Epoch: 16100, Total Loss:5.3052e+00
# Epoch: 16200, Total Loss:5.3127e+00
# Epoch: 16300, Total Loss:5.2988e+00
# Epoch: 16400, Total Loss:5.2919e+00
# Epoch: 16500, Total Loss:5.3036e+00
# Epoch: 16600, Total Loss:5.2899e+00
# Epoch: 16700, Total Loss:5.2922e+00
# Epoch: 16800, Total Loss:5.2964e+00
# Epoch: 16900, Total Loss:5.2934e+00
# Epoch: 17000, Total Loss:5.2948e+00
# Epoch: 17100, Total Loss:5.3010e+00
# Epoch: 17200, Total Loss:5.2904e+00
# Epoch: 17300, Total Loss:5.2905e+00
# Epoch: 17400, Total Loss:5.2875e+00
# Epoch: 17500, Total Loss:5.2937e+00
# Epoch: 17600, Total Loss:5.3276e+00
# Epoch: 17700, Total Loss:5.2970e+00
# Epoch: 17800, Total Loss:5.2905e+00
# Epoch: 17900, Total Loss:5.2903e+00
# Epoch: 18000, Total Loss:5.2860e+00
# Epoch: 18100, Total Loss:5.2933e+00
# Epoch: 18200, Total Loss:5.2843e+00
# Epoch: 18300, Total Loss:5.2892e+00
# Epoch: 18400, Total Loss:5.3026e+00
# Epoch: 18500, Total Loss:5.2859e+00
# Epoch: 18600, Total Loss:5.2867e+00
# Epoch: 18700, Total Loss:5.2897e+00
# Epoch: 18800, Total Loss:5.2935e+00
# Epoch: 18900, Total Loss:5.2880e+00
# Epoch: 19000, Total Loss:5.2899e+00
# Epoch: 19100, Total Loss:5.2888e+00
# Epoch: 19200, Total Loss:5.2865e+00
# Epoch: 19300, Total Loss:5.2937e+00
# Epoch: 19400, Total Loss:5.2825e+00
# Epoch: 19500, Total Loss:5.2891e+00
# Epoch: 19600, Total Loss:5.2834e+00
# Epoch: 19700, Total Loss:5.2846e+00
# Epoch: 19800, Total Loss:5.2911e+00
# Epoch: 19900, Total Loss:5.2861e+00
# Epoch: 20000, Total Loss:5.2840e+00
# Epoch: 20100, Total Loss:5.2839e+00
# Epoch: 20200, Total Loss:5.2938e+00
# Epoch: 20300, Total Loss:5.2913e+00
# Epoch: 20400, Total Loss:5.2882e+00
# Epoch: 20500, Total Loss:5.2795e+00
# Epoch: 20600, Total Loss:5.2889e+00
# Epoch: 20700, Total Loss:5.2812e+00
# Epoch: 20800, Total Loss:5.2837e+00
# Epoch: 20900, Total Loss:5.2864e+00
# Epoch: 21000, Total Loss:5.2830e+00
# Epoch: 21100, Total Loss:5.2843e+00
# Epoch: 21200, Total Loss:5.2889e+00
# Epoch: 21300, Total Loss:5.2871e+00
# Epoch: 21400, Total Loss:5.2855e+00
# Epoch: 21500, Total Loss:5.2824e+00
# Epoch: 21600, Total Loss:5.2855e+00
# Epoch: 21700, Total Loss:5.2873e+00
# Epoch: 21800, Total Loss:5.2828e+00
# Epoch: 21900, Total Loss:5.2984e+00
# Epoch: 22000, Total Loss:5.2820e+00
# Epoch: 22100, Total Loss:5.2815e+00
# Epoch: 22200, Total Loss:5.2879e+00
# Epoch: 22300, Total Loss:5.2771e+00
# Epoch: 22400, Total Loss:5.2867e+00
# Epoch: 22500, Total Loss:5.2779e+00
# Epoch: 22600, Total Loss:5.2792e+00
# Epoch: 22700, Total Loss:5.2770e+00
# Epoch: 22800, Total Loss:5.2848e+00
# Epoch: 22900, Total Loss:5.2808e+00
# Epoch: 23000, Total Loss:5.2791e+00
# Epoch: 23100, Total Loss:5.2990e+00
# Epoch: 23200, Total Loss:5.2750e+00
# Epoch: 23300, Total Loss:5.2801e+00
# Epoch: 23400, Total Loss:5.2908e+00
# Epoch: 23500, Total Loss:5.2857e+00
# Epoch: 23600, Total Loss:5.2755e+00
# Epoch: 23700, Total Loss:5.2874e+00
# Epoch: 23800, Total Loss:5.2807e+00
# Epoch: 23900, Total Loss:5.2953e+00
# Epoch: 24000, Total Loss:5.2927e+00
# Epoch: 24100, Total Loss:5.2782e+00
# Epoch: 24200, Total Loss:5.2788e+00
# Epoch: 24300, Total Loss:5.2772e+00
# Epoch: 24400, Total Loss:5.3014e+00
# Epoch: 24500, Total Loss:5.2776e+00
# Epoch: 24600, Total Loss:5.2727e+00
# Epoch: 24700, Total Loss:5.2747e+00
# Epoch: 24800, Total Loss:5.2824e+00
# Epoch: 24900, Total Loss:5.2785e+00
# Epoch: 25000, Total Loss:5.2738e+00
# Epoch: 25100, Total Loss:5.2777e+00
# Epoch: 25200, Total Loss:5.2740e+00
# Epoch: 25300, Total Loss:5.2798e+00
# Epoch: 25400, Total Loss:5.2760e+00
# Epoch: 25500, Total Loss:5.2874e+00
# Epoch: 25600, Total Loss:5.2926e+00
# Epoch: 25700, Total Loss:5.2777e+00
# Epoch: 25800, Total Loss:5.2728e+00
# Epoch: 25900, Total Loss:5.2738e+00
# Epoch: 26000, Total Loss:5.2713e+00
# Epoch: 26100, Total Loss:5.2760e+00
# Epoch: 26200, Total Loss:5.2773e+00
# Epoch: 26300, Total Loss:5.2737e+00
# Epoch: 26400, Total Loss:5.2757e+00
# Epoch: 26500, Total Loss:5.2891e+00
# Epoch: 26600, Total Loss:5.2992e+00
# Epoch: 26700, Total Loss:5.2744e+00
# Epoch: 26800, Total Loss:5.2767e+00
# Epoch: 26900, Total Loss:5.2740e+00
# Epoch: 27000, Total Loss:5.2708e+00
# Epoch: 27100, Total Loss:5.2804e+00
# Epoch: 27200, Total Loss:5.2769e+00
# Epoch: 27300, Total Loss:5.2938e+00
# Epoch: 27400, Total Loss:5.2784e+00
# Epoch: 27500, Total Loss:5.2740e+00
# Epoch: 27600, Total Loss:5.2707e+00
# Epoch: 27700, Total Loss:5.2757e+00
# Epoch: 27800, Total Loss:5.2782e+00
# Epoch: 27900, Total Loss:5.2794e+00
# Epoch: 28000, Total Loss:5.2730e+00
# Epoch: 28100, Total Loss:5.2717e+00
# Epoch: 28200, Total Loss:5.2732e+00
# Epoch: 28300, Total Loss:5.2696e+00
# Epoch: 28400, Total Loss:5.2709e+00
# Epoch: 28500, Total Loss:5.2706e+00
# Epoch: 28600, Total Loss:5.2815e+00
# Epoch: 28700, Total Loss:5.2774e+00
# Epoch: 28800, Total Loss:5.2700e+00
# Epoch: 28900, Total Loss:5.2683e+00
# Epoch: 29000, Total Loss:5.2726e+00
# Epoch: 29100, Total Loss:5.2744e+00
# Epoch: 29200, Total Loss:5.2852e+00
# Epoch: 29300, Total Loss:5.2836e+00
# Epoch: 29400, Total Loss:5.2690e+00
# Epoch: 29500, Total Loss:5.2935e+00
# Epoch: 29600, Total Loss:5.2725e+00
# Epoch: 29700, Total Loss:5.2761e+00
# Epoch: 29800, Total Loss:5.2752e+00
# Epoch: 29900, Total Loss:5.2693e+00
# Epoch: 30000, Total Loss:5.2815e+00
# Epoch: 30100, Total Loss:5.2719e+00
# Epoch: 30200, Total Loss:5.2707e+00
# Epoch: 30300, Total Loss:5.2685e+00
# Epoch: 30400, Total Loss:5.2779e+00
# Epoch: 30500, Total Loss:5.2710e+00
# Epoch: 30600, Total Loss:5.2803e+00
# Epoch: 30700, Total Loss:5.2694e+00
# Epoch: 30800, Total Loss:5.2691e+00
# Epoch: 30900, Total Loss:5.2813e+00
# Epoch: 31000, Total Loss:5.2853e+00
# Epoch: 31100, Total Loss:5.2735e+00
# Epoch: 31200, Total Loss:5.2667e+00
# Epoch: 31300, Total Loss:5.2769e+00
# Epoch: 31400, Total Loss:5.2729e+00
# Epoch: 31500, Total Loss:5.2699e+00
# Epoch: 31600, Total Loss:5.2724e+00
# Epoch: 31700, Total Loss:5.2763e+00
# Epoch: 31800, Total Loss:5.2677e+00
# Epoch: 31900, Total Loss:5.2685e+00
# Epoch: 32000, Total Loss:5.2682e+00
# Epoch: 32100, Total Loss:5.2727e+00
# Epoch: 32200, Total Loss:5.2735e+00
# Epoch: 32300, Total Loss:5.2764e+00
# Epoch: 32400, Total Loss:5.2673e+00
# Epoch: 32500, Total Loss:5.2671e+00
# Epoch: 32600, Total Loss:5.2673e+00
# Epoch: 32700, Total Loss:5.2742e+00
# Epoch: 32800, Total Loss:5.2821e+00
# Epoch: 32900, Total Loss:5.2690e+00
# Epoch: 33000, Total Loss:5.2666e+00
# Epoch: 33100, Total Loss:5.2659e+00
# Epoch: 33200, Total Loss:5.2851e+00
# Epoch: 33300, Total Loss:5.2737e+00
# Epoch: 33400, Total Loss:5.2759e+00
# Epoch: 33500, Total Loss:5.2772e+00
# Epoch: 33600, Total Loss:5.2650e+00
# Epoch: 33700, Total Loss:5.2650e+00
# Epoch: 33800, Total Loss:5.2698e+00
# Epoch: 33900, Total Loss:5.2658e+00
# Epoch: 34000, Total Loss:5.2695e+00
# Epoch: 34100, Total Loss:5.2669e+00
# Epoch: 34200, Total Loss:5.2691e+00
# Epoch: 34300, Total Loss:5.2721e+00
# Epoch: 34400, Total Loss:5.2665e+00
# Epoch: 34500, Total Loss:5.2670e+00
# Epoch: 34600, Total Loss:5.2723e+00
# Epoch: 34700, Total Loss:5.2672e+00
# Epoch: 34800, Total Loss:5.2728e+00
# Epoch: 34900, Total Loss:5.2675e+00
# Epoch: 35000, Total Loss:5.2654e+00
# Epoch: 35100, Total Loss:5.2771e+00
# Epoch: 35200, Total Loss:5.2628e+00
# Epoch: 35300, Total Loss:5.2641e+00
# Epoch: 35400, Total Loss:5.2655e+00
# Epoch: 35500, Total Loss:5.2698e+00
# Epoch: 35600, Total Loss:5.2646e+00
# Epoch: 35700, Total Loss:5.2633e+00
# Epoch: 35800, Total Loss:5.2694e+00
# Epoch: 35900, Total Loss:5.2704e+00
# Epoch: 36000, Total Loss:5.2721e+00
# Epoch: 36100, Total Loss:5.2706e+00
# Epoch: 36200, Total Loss:5.2652e+00
# Epoch: 36300, Total Loss:5.2664e+00
# Epoch: 36400, Total Loss:5.2706e+00
# Epoch: 36500, Total Loss:5.2636e+00
# Epoch: 36600, Total Loss:5.3068e+00
# Epoch: 36700, Total Loss:5.2729e+00
# Epoch: 36800, Total Loss:5.2677e+00
# Epoch: 36900, Total Loss:5.2748e+00
# Epoch: 37000, Total Loss:5.2686e+00
# Epoch: 37100, Total Loss:5.2616e+00
# Epoch: 37200, Total Loss:5.2686e+00
# Epoch: 37300, Total Loss:5.2642e+00
# Epoch: 37400, Total Loss:5.2703e+00
# Epoch: 37500, Total Loss:5.2713e+00
# Epoch: 37600, Total Loss:5.2673e+00
# Epoch: 37700, Total Loss:5.2670e+00
# Epoch: 37800, Total Loss:5.2645e+00
# Epoch: 37900, Total Loss:5.2650e+00
# Epoch: 38000, Total Loss:5.2630e+00
# Epoch: 38100, Total Loss:5.2660e+00
# Epoch: 38200, Total Loss:5.2676e+00
# Epoch: 38300, Total Loss:5.2703e+00
# Epoch: 38400, Total Loss:5.2707e+00
# Epoch: 38500, Total Loss:5.2669e+00
# Epoch: 38600, Total Loss:5.2745e+00
# Epoch: 38700, Total Loss:5.2688e+00
# Epoch: 38800, Total Loss:5.2641e+00
# Epoch: 38900, Total Loss:5.2618e+00
# Epoch: 39000, Total Loss:5.2657e+00
# Epoch: 39100, Total Loss:5.2629e+00
# Epoch: 39200, Total Loss:5.2730e+00
# Epoch: 39300, Total Loss:5.2676e+00
# Epoch: 39400, Total Loss:5.2660e+00
# Epoch: 39500, Total Loss:5.2660e+00
# Epoch: 39600, Total Loss:5.2618e+00
# Epoch: 39700, Total Loss:5.2651e+00
# Epoch: 39800, Total Loss:5.2637e+00
# Epoch: 39900, Total Loss:5.2650e+00
# Epoch: 40000, Total Loss:5.2610e+00
# Adam Training Time : 49.379456 secs
# Starting L-BFGS Optimization
# L-BFGS training time : 18.742 secs
# ✅ Saved final model parameters to PINNs_params_arch_58_58_58_2.pkl

# %% [markdown]
# # Displacement Plots

# %%
# Create evaluation points
x_points = np.linspace(-side_length, side_length, 200 + 1)
y_points = np.linspace(-side_length, side_length, 200 + 1)
X, Y = np.meshgrid(x_points, y_points, indexing='ij')
X, Y = X.flatten(), Y.flatten()
eval_points = np.array([X, Y]).T

with open('PINNs_results.json', 'r') as f:
    data_results = json.load(f)

with open('PINNs_evaluation.json', 'r') as f:
    data_eval = json.load(f)

# Slice results data
domain_pts = data_results['domain_pts']
y_results = data_results['y_results']
y_gt = data_results['y_gt']

arch = data_eval['arch']
l2_rel = data_eval['l2_rel']

# Exact solution
u_exact = np.array(y_gt) # (n,)
u_exact_magnitude = np.sqrt(u_exact[:, 0]**2 + u_exact[:, 1]**2)

# Contour plot settings
# For a consistent scale across all time steps
u_min = u_exact_magnitude.min()
u_max = u_exact_magnitude.max()
# Create n levels between u_min & u_max:
num_levels = 80
levels = np.linspace(u_min, u_max, num_levels)

# Exact solution
fig1 = plt.figure(1, figsize=(6, 5))
ax1 = fig1.add_subplot(1, 1, 1)
sc1 = ax1.tricontourf(X, Y, u_exact_magnitude,
                      levels=levels, cmap='viridis')
ax1.set_title('Exact Solution')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_aspect('equal', adjustable='box')
fig1.colorbar(sc1, ax=ax1, shrink=0.75, label='Solution Value')

# Approximate solution
for idx, architecture in arch.items():
    # Get the approximate solution for this architecture
    u_approx = np.array(y_results[idx])  # (n,)
    u_approx_magnitude = np.sqrt(u_approx[:, 0]**2 + u_approx[:, 1]**2)

    # Contour plot settings
    # For a consistent scale across all time steps
    u_min = u_approx_magnitude.min()
    u_max = u_approx_magnitude.max()
    # Create n levels between u_min & u_max:
    num_levels = 80
    levels = np.linspace(u_min, u_max, num_levels)

    # Contour plot
    fig2 = plt.figure(2, figsize=(6, 5))
    ax2 = fig2.add_subplot(1, 1, 1)
    sc2 = ax2.tricontourf(X, Y, u_approx_magnitude,
                          levels=levels, cmap='viridis')
    ax2.set_title(f"PINNs Solution (Architecture={architecture})")
    ax2.set_xlabel("x")
    ax2.set_ylabel("y")
    ax2.set_aspect('equal', adjustable='box')
    fig2.colorbar(sc2, ax=ax2, shrink=0.75, label='Solution Value')

    # Save figures
    # fig_dir = f'./fig/arch_{idx}'
    # if not os.path.exists(fig_dir):
    #     os.makedirs(fig_dir, exist_ok=True)

    # filename = os.path.join(fig_dir, f'sol_{idx}.png')
    # fig2.savefig(filename, dpi=300, bbox_inches='tight')
    plt.show()
    plt.close(fig2)

# %% [markdown]
# # Deformed Configuration

# %%
# Find the boundary indices
eval_points = onp.array(eval_points)
boundary_idx = onp.where((eval_points[:, 0] == -side_length) | (eval_points[:, 0] == side_length) | (eval_points[:, 1] == -side_length) | (eval_points[:, 1] == side_length))

# Exact solution
fig_3 = plt.figure(3, figsize=(6, 5))
ax_3 = fig_3.add_subplot(1, 1, 1)
ax_3.plot(eval_points[boundary_idx, 0], eval_points[boundary_idx, 1], 'k.', markersize=1, label='Boundary')
ax_3.plot(eval_points[boundary_idx, 0] + u_exact[boundary_idx, 0], eval_points[boundary_idx, 1] + u_exact[boundary_idx, 1], 'r.', markersize=2, label='Reference')
ax_3.set_title('Displacement Configuration (Exact Solution)')
ax_3.set_xlabel('x')
ax_3.set_ylabel('y')
ax_3.set_aspect('equal', adjustable='box')
# fig_3.savefig('./fig/ref_config.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close(fig_3)

for idx, architecture in arch.items():
    u_approx_converted = onp.array(y_results[idx])


    # Approx solution
    fig_4 = plt.figure(4, figsize=(6, 5))
    ax_4 = fig_4.add_subplot(1, 1, 1)
    ax_4.plot(eval_points[boundary_idx, 0], eval_points[boundary_idx, 1], 'k.', markersize=1, label='Boundary')
    ax_4.plot(eval_points[boundary_idx, 0] + u_approx_converted[boundary_idx, 0], eval_points[boundary_idx, 1] + u_approx_converted[boundary_idx, 1], 'r.', markersize=2, label='Reference')
    ax_4.set_title('Deformed Configuration (Approx Solution)')
    ax_4.set_xlabel('x')
    ax_4.set_ylabel('y')
    ax_4.set_aspect('equal', adjustable='box')
    # fig_3.savefig('./fig/ref_config.png', dpi=300, bbox_inches='tight')
    plt.show()
    plt.close(fig_4)

# %% [markdown]
# # Error Plots

# %%
# Exact solution
u_exact = np.array(y_gt) # (n,)
u_exact_magnitude = np.sqrt(u_exact[:, 0]**2 + u_exact[:, 1]**2)

# Contour plot settings
levels = 80

# Approximate solution
for idx, architecture in arch.items():
    # Get the approximate solution for this architecture
    u_approx = np.array(y_results[idx])  # (n,)
    u_approx_magnitude = np.sqrt(u_approx[:, 0]**2 + u_approx[:, 1]**2)
    error_val = np.abs(u_approx_magnitude - u_exact_magnitude)

    # Contour plot
    fig_error = plt.figure(1, figsize=(6, 5))
    ax_error = fig_error.add_subplot(1, 1, 1)
    sc_error = ax_error.tricontourf(X, Y, error_val,
                                    levels=levels, cmap='viridis')
    ax_error.set_title(f"Error Map (Architecture={architecture})")
    ax_error.set_xlabel("x")
    ax_error.set_ylabel("y")
    ax_error.set_aspect('equal', adjustable='box')
    fig_error.colorbar(sc_error, ax=ax_error, shrink=0.75, label='Error Value')

    plt.show()
    plt.close(fig1)

# %% [markdown]
# # Loss Plots

# %%
with open('PINNs_evaluation.json', 'r') as f:
    data_eval = json.load(f)

# Slice results data
arch = data_eval['arch']
l2_rel = data_eval['l2_rel']
losses_adam = data_eval['losses_adam']

for idx, architecture in arch.items():
    loss_adam_history = losses_adam[idx]

    plt.style.use('seaborn-v0_8-whitegrid')
    fig_loss, ax_loss = plt.subplots(figsize=(12, 8))

    # Generate X-axis (Adam)
    num_data_points = len(loss_history['total'])
    adam_epochs = [(i + 1) * 100 for i in range(num_data_points)]
    # Find the last epoch number from Adam to start the L-BFGS count
    last_adam_epoch = adam_epochs[-1] if adam_epochs else 0

    # Plot Each Loss Term
    for loss_name in loss_adam_history.keys():
        ax_loss.plot(adam_epochs, loss_adam_history[loss_name], label=loss_name.capitalize())
    # ax_loss.plot(epochs, loss_history['dirichlet1'], label=loss_name.capitalize())
    # ax_loss.plot(epochs, loss_history['dirichlet2'], label=loss_name.capitalize())

    ax_loss.set_yscale('log') # Use a logarithmic scale
    ax_loss.legend(loc='upper right', fontsize=10)
    ax_loss.set_xlabel('Epoch')
    ax_loss.set_ylabel('Loss (Log Scale)')
    ax_loss.set_title(f'Loss History')
    ax_loss.tick_params(axis='both', which='major', labelsize=12)
    plt.tight_layout()
    plt.show()
    plt.close(fig_loss)

# %%
l2_rel
# Out:
# {'0': 0.1897970288991928}
